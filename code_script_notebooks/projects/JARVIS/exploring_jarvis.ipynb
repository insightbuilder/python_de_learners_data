# %%
# !git clone https://github.com/microsoft/JARVIS.git
# Out:
# Cloning into 'JARVIS'...
# remote: Enumerating objects: 357, done.
# remote: Counting objects: 100% (188/188), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 357 (delta 137), reused 114 (delta 99), pack-reused 169
# Receiving objects: 100% (357/357), 3.42 MiB | 18.63 MiB/s, done.
# Resolving deltas: 100% (188/188), done.

# %%
# !cd /content/JARVIS/server && pip install -r requirements.txt

# %%
# !cd /content/JARVIS/server/models && bash download.sh

# %%
# !wget https://github.com/microsoft/JARVIS/blob/main/server/public/examples/d.jpg

# %%
# !cd /content/JARVIS/server && python awesome_chat.py --config config.yaml --mode cli
# Out:
# 2023-04-10 00:49:09.240008: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Welcome to Jarvis! A collaborative system that consists of an LLM as the controller and numerous expert models as collaborative executors. Jarvis can plan tasks, schedule Hugging Face models, generate friendly responses based on your requests, and help you with many things. Please enter your request (`exit` to exit).
# [ User ]: Given a collection of image A: /content/a.jpg, B: /content/b.jpg, C: /content/c.jpg, please tell me how many zebras in these picture?
# Incorrect path or url, URLs must start with `http://` or `https://`, and public//content/c.jpg is not a valid path
# Traceback (most recent call last):
#   File "/content/JARVIS/server/awesome_chat.py", line 608, in model_inference
#     inference_result = huggingface_model_inference(model_id, data, task)
#   File "/content/JARVIS/server/awesome_chat.py", line 450, in huggingface_model_inference
# ...
