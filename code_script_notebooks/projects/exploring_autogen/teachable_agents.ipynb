# %%
import openai
from dotenv import load_dotenv
import autogen
from autogen.agentchat.contrib.teachable_agent import TeachableAgent
from autogen.agentchat.contrib.text_analyzer_agent import TextAnalyzerAgent
from custom_teachable import CustomTeachableAgent
from autogen import ConversableAgent, UserProxyAgent
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 from dotenv import load_dotenv
#       3 import autogen
# ----> 4 from autogen.agentchat.contrib.teachable_agent import TeachableAgent
#       5 from autogen.agentchat.contrib.text_analyzer_agent import TextAnalyzerAgent
#       6 from custom_teachable import CustomTeachableAgent
#
# ModuleNotFoundError: No module named 'autogen.agentchat.contrib.teachable_agent'

# %%
config_list = autogen.config_list_from_dotenv(
    dotenv_file_path='.env', # If None the function will try to find in the working directory
    filter_dict={
        "model": {
            "gpt-4",
            "gpt-3.5-turbo",
        }
    }
)

config_list

# %%
cache_seed = None

# %%
# Start by instantiating any agent that inherits from ConversableAgent.
teachable_agent = ConversableAgent(
    name="teachable_agent",  # The name is flexible, but should not contain spaces to work in group chat.
    llm_config={"config_list":config_list,
                "timeout": 120, 
                "cache_seed": None},  # Disable caching.
)

# %%
llm_config={
    "config_list": config_list, 
    "timeout": 120, 
    "cache_seed": cache_seed
}

verbosity = 3  # 0 for basic info, 1 to add memory operations, 2 for analyzer messages, 3 for memo lists.
recall_threshold = 3  # Higher numbers allow more (but less relevant) memos to be recalled.

teachable_agent_system_message = """
You are the TeachableAgent, representing a CRM (Customer Relationship Management) system.
Your role involves the following key interactions with the user:
1. Information Gathering: Engage in conversations to collect data about people (names, job titles, contact details), tasks, and any specific problem-solution scenarios.
2. Data Analysis and Storage: Use your analysis capabilities (via TextAnalyzerAgent) to determine what information from the conversation is relevant for CRM storage. This includes personal details, task-related information, and question-answer pairs.
3. Data Retrieval: When a user makes inquiries, retrieve relevant information from your database. This involves using past conversation details or CRM entries to provide helpful responses.
4. User Interaction: Maintain a conversational tone, guiding users to provide information or ask questions relevant to CRM activities. Be proactive in clarifying details and asking follow-up questions for comprehensive data collection.
Always consider the context of the user's queries and comments for effective CRM management. Your interactions should be tailored to build and maintain strong, informative user relationships. You will work closely with TextAnalyzerAgent and your MemoStore to ensure accurate data processing and storage."""

teachable_agent = CustomTeachableAgent(
    name="teachableagent",
    llm_config=llm_config,
    system_message=teachable_agent_system_message,
    teach_config={
        "verbosity": verbosity,
        "recall_threshold": recall_threshold,
    },
)

text_analyzer_system_message = """
You are an expert in text analysis with a focus on CRM-like data extraction.
The user will give you TEXT to analyze.
The user will give you analysis INSTRUCTIONS copied twice, at both the beginning and the end.
Your analysis should focus on identifying and categorizing the following types of information from the TEXT:
1. Personal Details: Recognize and extract any mention of people, including names and relevant personal details (e.g., job titles, relationships, contact information). Structure these details for CRM storage.
2. Task-Related Information: Detect if the TEXT involves tasks or problems. Extract and summarize tasks, advice, and solutions, keeping in mind future applicability and generalization.
3. Question-Answer Pairs: Identify information that answers specific questions. Extract these pairs for memory storage, focusing on clear, concise answers to potential user queries.
You will follow these INSTRUCTIONS in analyzing the TEXT, then give the results of your expert analysis in the format requested. Your output should be clear and structured, suitable for immediate use in CRM and memory systems."""

# %%
teachable_agent.analyzer = TextAnalyzerAgent(
    name="TextAnalyzerAgent",
    system_message=text_analyzer_system_message,
    llm_config=llm_config
)

# text_analyzer_system_message = """You are an expert in text analysis.
# The user will give you TEXT to analyze.
# The user will give you analysis INSTRUCTIONS copied twice, at both the beginning and the end.
# You will follow these INSTRUCTIONS in analyzing the TEXT, then give the results of your expert analysis in the format requested.
# Most importantly of all, you only care about text that deals with cats.  
# If TEXT does not relate to cats, respond with no.
# If TEXT does not relate to cats, you will respond with one word, and one word only: no
# """
# teachable_agent.analyzer = TextAnalyzerAgent(
#     system_message=text_analyzer_system_message,
#     llm_config=llm_config
# )

# %%
try:
    from termcolor import colored
except ImportError:

    def colored(x, *args, **kwargs):
        return x

# %%
# Create the agents.
print(colored("\nLoading previous memory (if any) from disk.", "light_cyan"))
user = UserProxyAgent("user", human_input_mode="ALWAYS")
# Out:
# Loading previous memory (if any) from disk.

# %%
# Start the chat.
teachable_agent.initiate_chat(user, message="Greetings, I'm a teachable user assistant! What's on your mind today?")
# Out:
# teachableagent (to user):
#
# Greetings, I'm a teachable user assistant! What's on your mind today?
#
# --------------------------------------------------------------------------------
# Provide feedback to teachableagent. Press enter to skip and use auto-reply, or type 'exit' to end the conversation:  Who was the first man to land on moon
# user (to teachableagent):
#
# Who was the first man to land on moon
#
# --------------------------------------------------------------------------------
# teachableagent (to user):
#
# The first man to land on the moon was Neil Armstrong on July 20, 1969, as part of the Apollo 11 mission.
#
# --------------------------------------------------------------------------------
# Provide feedback to teachableagent. Press enter to skip and use auto-reply, or type 'exit' to end the conversation:  Which is te best open source model at present
# user (to teachableagent):
#
# Which is te best open source model at present
#
# --------------------------------------------------------------------------------
# teachableagent (to user):
#
# There are a great number of powerful and versatile open-source models available, and the "best" one largely depends on the specific task you're trying to accomplish. Are you looking for a model for natural language processing, computer vision, recommendation systems, or something else? Providing more context will allow me to give you a more accurate response.
#
# --------------------------------------------------------------------------------
# Provide feedback to teachableagent. Press enter to skip and use auto-reply, or type 'exit' to end the conversation:  The best open source model today is Mistral-7B in the languagle modeling segment
# user (to teachableagent):
#
# The best open source model today is Mistral-7B in the languagle modeling segment
#
# --------------------------------------------------------------------------------
# teachableagent (to user):
#
# Alright, thank you for this information. Now, if I may ask, are you looking for additional details about Mistral-7B or were you looking for how this model can be applied in a specific context?
#
# --------------------------------------------------------------------------------
# Provide feedback to teachableagent. Press enter to skip and use auto-reply, or type 'exit' to end the conversation:  I was looking for additional details
# user (to teachableagent):
#
# I was looking for additional details
#
# --------------------------------------------------------------------------------
# teachableagent (to user):
#
# I'm sorry, but I couldn't find any specific information on an open-source language model called "Mistral-7B". It's possible there could be a misunderstanding or miscommunication of the model name.
#
# However, in the field of language modeling, the best open source model according to popular opinion is GPT-3 by OpenAI, BERT by Google, or even transformers by Hugging Face. Is it possible you were referring to one of these? If you have other models in mind or need information on a different topic, feel free to let me know!
#
# --------------------------------------------------------------------------------
# Provide feedback to teachableagent. Press enter to skip and use auto-reply, or type 'exit' to end the conversation:  Mistral-7B is one of the top class models, make a note of it please
# user (to teachableagent):
#
# Mistral-7B is one of the top class models, make a note of it please
#
# --------------------------------------------------------------------------------
# teachableagent (to user):
#
# Alright, I'll make a note of it. I'll store the information that "Mistral-7B" is considered a top class model in the field of language modeling.
#
# Would you like to provide more information or specifications about this model? Maybe its unique features or inherent advantages over others? That could be valuable data for future reference.
#
# --------------------------------------------------------------------------------
# Provide feedback to teachableagent. Press enter to skip and use auto-reply, or type 'exit' to end the conversation:  exit

# %%
# Let the teachable agent remember things that should be learned from this chat.
teachable_agent.learn_from_user_feedback()
# Out:
# REVIEWING CHAT FOR USER TEACHINGS TO REMEMBER
#   0%|          | 0/5 [00:00<?, ?it/s]
# teachableagent (to TextAnalyzerAgent):
#
# Who was the first man to land on moon
#
# --------------------------------------------------------------------------------
# teachableagent (to TextAnalyzerAgent):
#
# Does the TEXT include any details that are important for understanding customer needs, preferences, or intentions, such as product interest or timeline? Respond with yes or no.
#
# --------------------------------------------------------------------------------
# TextAnalyzerAgent (to teachableagent):
#
# No
#
# --------------------------------------------------------------------------------
#  20%|██        | 1/5 [00:01<00:06,  1.57s/it]
# teachableagent (to TextAnalyzerAgent):
#
# Which is te best open source model at present
#
# --------------------------------------------------------------------------------
# teachableagent (to TextAnalyzerAgent):
#
# Does the TEXT include any details that are important for understanding customer needs, preferences, or intentions, such as product interest or timeline? Respond with yes or no.
#
# --------------------------------------------------------------------------------
# TextAnalyzerAgent (to teachableagent):
#
# No
#
# --------------------------------------------------------------------------------
#  40%|████      | 2/5 [00:03<00:05,  1.67s/it]
# teachableagent (to TextAnalyzerAgent):
#
# The best open source model today is Mistral-7B in the languagle modeling segment
#
# --------------------------------------------------------------------------------
# teachableagent (to TextAnalyzerAgent):
#
# Does the TEXT include any details that are important for understanding customer needs, preferences, or intentions, such as product interest or timeline? Respond with yes or no.
#
# --------------------------------------------------------------------------------
# TextAnalyzerAgent (to teachableagent):
#
# No
#
# --------------------------------------------------------------------------------
#  60%|██████    | 3/5 [00:04<00:02,  1.42s/it]
# teachableagent (to TextAnalyzerAgent):
#
# I was looking for additional details
#
# --------------------------------------------------------------------------------
# teachableagent (to TextAnalyzerAgent):
#
# Does the TEXT include any details that are important for understanding customer needs, preferences, or intentions, such as product interest or timeline? Respond with yes or no.
#
# --------------------------------------------------------------------------------
# TextAnalyzerAgent (to teachableagent):
#
# No
#
# --------------------------------------------------------------------------------
#  80%|████████  | 4/5 [00:06<00:01,  1.60s/it]
# teachableagent (to TextAnalyzerAgent):
#
# Mistral-7B is one of the top class models, make a note of it please
#
# --------------------------------------------------------------------------------
# teachableagent (to TextAnalyzerAgent):
#
# Does the TEXT include any details that are important for understanding customer needs, preferences, or intentions, such as product interest or timeline? Respond with yes or no.
#
# --------------------------------------------------------------------------------
# TextAnalyzerAgent (to teachableagent):
#
# Yes
#
# --------------------------------------------------------------------------------
# teachableagent (to TextAnalyzerAgent):
#
# Mistral-7B is one of the top class models, make a note of it please
#
# --------------------------------------------------------------------------------
# teachableagent (to TextAnalyzerAgent):
#
# Extract all details from the TEXT that are important for CRM, including any mentions of product preferences, customer intentions, timeframes, or other relevant details.
#
# --------------------------------------------------------------------------------
# TextAnalyzerAgent (to teachableagent):
#
# # CRM Data Extraction
#
# ## Product Preferences:
# - The product in question is "Mistral-7B," which is stated to be a top-class model.
#
# ## Customer Intentions:
# - The customer intends to make a distinguishing note of the product, which suggests a high degree of interest or perhaps a future purchase intention.
#
# ## Timeframes:
# - No specific timeframes were mentioned in the text.
#
# ## Other Relevant Details:
# - The praise for the "Mistral-7B" as a top-class model could suggest preferences for high-quality or advanced features. This assumption is however not solid and additional data would be useful to confirm it.
#
# --------------------------------------------------------------------------------
# teachableagent (to TextAnalyzerAgent):
#
# Mistral-7B is one of the top class models, make a note of it please
#
# --------------------------------------------------------------------------------
# teachableagent (to TextAnalyzerAgent):
#
# If someone asked for a summary of this customer's needs or preferences based on the TEXT, what question would they be asking? Provide the question only.
#
# --------------------------------------------------------------------------------
# TextAnalyzerAgent (to teachableagent):
#
# What is the model preference indicated by the customer in the text?
#
# --------------------------------------------------------------------------------
#
# REMEMBER THIS CRM INFORMATION
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   0%|          | 0.00/79.3M [00:00<?, ?iB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   0%|          | 2.00k/79.3M [00:00<3:24:30, 6.78kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   0%|          | 51.0k/79.3M [00:00<16:43, 82.9kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   0%|          | 123k/79.3M [00:01<13:15, 104kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   0%|          | 210k/79.3M [00:01<07:11, 192kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   0%|          | 243k/79.3M [00:01<10:04, 137kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   0%|          | 316k/79.3M [00:02<06:41, 206kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   0%|          | 355k/79.3M [00:02<07:37, 181kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   1%|          | 465k/79.3M [00:02<07:02, 196kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   1%|          | 633k/79.3M [00:03<04:01, 342kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   1%|          | 687k/79.3M [00:03<03:55, 350kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   1%|          | 736k/79.3M [00:03<03:57, 347kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   1%|          | 780k/79.3M [00:03<03:49, 359kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   1%|          | 823k/79.3M [00:03<03:57, 346kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   1%|          | 862k/79.3M [00:03<03:50, 356kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   1%|          | 901k/79.3M [00:03<04:11, 328kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   1%|          | 958k/79.3M [00:03<03:37, 379kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   1%|          | 0.98M/79.3M [00:04<03:56, 348kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   1%|▏         | 1.03M/79.3M [00:04<03:53, 351kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   1%|▏         | 1.09M/79.3M [00:04<03:44, 365kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   1%|▏         | 1.14M/79.3M [00:04<06:24, 213kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   2%|▏         | 1.24M/79.3M [00:05<07:36, 179kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   2%|▏         | 1.44M/79.3M [00:06<04:51, 280kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   2%|▏         | 1.53M/79.3M [00:06<04:39, 292kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   2%|▏         | 1.61M/79.3M [00:06<04:52, 279kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   2%|▏         | 1.71M/79.3M [00:06<04:36, 295kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:
iB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   6%|▌         | 4.87M/79.3M [00:15<02:30, 518kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   6%|▋         | 4.96M/79.3M [00:16<02:13, 583kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   6%|▋         | 5.03M/79.3M [00:16<02:11, 593kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   6%|▋         | 5.09M/79.3M [00:16<02:12, 587kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   6%|▋         | 5.14M/79.3M [00:16<03:23, 381kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   7%|▋         | 5.19M/79.3M [00:17<07:25, 175kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   7%|▋         | 5.58M/79.3M [00:17<02:54, 442kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   7%|▋         | 5.64M/79.3M [00:17<02:56, 439kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   7%|▋         | 5.88M/79.3M [00:18<01:55, 670kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   8%|▊         | 5.97M/79.3M [00:18<02:03, 625kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   8%|▊         | 6.05M/79.3M [00:18<01:56, 659kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   8%|▊         | 6.14M/79.3M [00:18<02:02, 625kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   8%|▊         | 6.21M/79.3M [00:18<02:13, 575kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   8%|▊         | 6.27M/79.3M [00:18<02:08, 596kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   8%|▊         | 6.34M/79.3M [00:18<02:05, 612kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   8%|▊         | 6.40M/79.3M [00:19<02:08, 596kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   8%|▊         | 6.46M/79.3M [00:19<02:15, 563kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   8%|▊         | 6.56M/79.3M [00:19<02:05, 606kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   8%|▊         | 6.62M/79.3M [00:19<02:11, 579kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   8%|▊         | 6.69M/79.3M [00:19<02:04, 611kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   9%|▊         | 6.75M/79.3M [00:19<02:05, 608kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   9%|▊         | 6.82M/79.3M [00:19<02:42, 469kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   9%|▊         | 6.87M/79.3M [00:20<03:43, 340kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   9%|▊         | 6.92M/79.3M [00:20<03:31, 358kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   9%|▉         | 6.99M/79.3M [00:20<02:57, 427kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   9%|▉         | 7.04M/79.3M [00:20<03:49, 330kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   9%|▉         | 7.10M/79.3M [00:21<05:04, 249kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   9%|▉         | 7.17M/79.3M [00:21<04:02, 312kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   9%|▉         | 7.24M/79.3M [00:21<05:07, 246kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   9%|▉         | 7.27M/79.3M [00:21<06:11, 203kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   9%|▉         | 7.50M/79.3M [00:22<03:29, 360kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  10%|▉         | 7.63M/79.3M [00:22<03:33, 353kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  10%|▉         | 7.77M/79.3M [00:23<04:49, 260kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  10%|█         | 7.98M/79.3M [00:23<03:42, 336kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  10%|█         | 8.08M/79.3M [00:24<03:59, 312kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  10%|█         | 8.20M/79.3M [00:24<03:59, 311kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  10%|█         | 8.32M/79.3M [00:25<04:03, 306kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  11%|█         | 8.43M/79.3M [00:25<04:03, 305kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  11%|█         | 8.51M/79.3M [00:26<05:26, 227kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  11%|█         | 8.68M/79.3M [00:26<04:26, 278kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  11%|█         | 8.76M/79.3M [00:26<03:49, 322kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  11%|█         | 8.81M/79.3M [00:27<04:28, 276kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  11%|█         | 8.86M/79.3M [00:27<05:25, 227kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  11%|█▏        | 8.96M/79.3M [00:28<06:23, 193kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  11%|█▏        | 9.06M/79.3M [00:28<05:44, 214kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  12%|█▏        | 9.16M/79.3M [00:29<05:26, 225kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  12%|█▏        | 9.28M/79.3M [00:29<04:37, 265kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  12%|█▏        | 9.38M/79.3M [00:29<04:40, 262kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:
iB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  90%|████████▉ | 71.4M/79.3M [02:26<00:13, 621kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  90%|█████████ | 71.4M/79.3M [02:26<00:12, 675kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  90%|█████████ | 71.5M/79.3M [02:27<00:11, 698kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  90%|█████████ | 71.6M/79.3M [02:27<00:15, 528kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  90%|█████████ | 71.7M/79.3M [02:27<00:15, 509kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  90%|█████████ | 71.7M/79.3M [02:27<00:20, 397kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  91%|█████████ | 71.8M/79.3M [02:27<00:13, 599kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  91%|█████████ | 71.9M/79.3M [02:29<00:45, 172kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  92%|█████████▏| 72.8M/79.3M [02:29<00:07, 928kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  92%|█████████▏| 73.1M/79.3M [02:29<00:07, 881kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  92%|█████████▏| 73.4M/79.3M [02:29<00:07, 847kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  93%|█████████▎| 73.5M/79.3M [02:30<00:07, 828kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  93%|█████████▎| 73.7M/79.3M [02:30<00:06, 848kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  93%|█████████▎| 73.8M/79.3M [02:30<00:06, 850kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  93%|█████████▎| 73.9M/79.3M [02:30<00:06, 866kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  93%|█████████▎| 74.1M/79.3M [02:30<00:07, 771kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  93%|█████████▎| 74.1M/79.3M [02:30<00:06, 782kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  94%|█████████▎| 74.2M/79.3M [02:31<00:06, 822kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  94%|█████████▎| 74.3M/79.3M [02:31<00:06, 806kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  94%|█████████▍| 74.5M/79.3M [02:31<00:05, 923kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  94%|█████████▍| 74.6M/79.3M [02:31<00:05, 903kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  94%|█████████▍| 74.7M/79.3M [02:31<00:05, 820kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  94%|█████████▍| 74.7M/79.3M [02:31<00:05, 822kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  94%|█████████▍| 74.8M/79.3M [02:31<00:05, 829kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  94%|█████████▍| 74.9M/79.3M [02:31<00:05, 829kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  95%|█████████▍| 75.0M/79.3M [02:31<00:05, 890kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  95%|█████████▍| 75.1M/79.3M [02:32<00:05, 802kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  95%|█████████▍| 75.2M/79.3M [02:32<00:05, 787kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  95%|█████████▍| 75.3M/79.3M [02:32<00:04, 860kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  95%|█████████▌| 75.4M/79.3M [02:32<00:04, 924kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  95%|█████████▌| 75.5M/79.3M [02:32<00:04, 936kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  95%|█████████▌| 75.6M/79.3M [02:32<00:03, 989kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  95%|█████████▌| 75.7M/79.3M [02:32<00:04, 921kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  96%|█████████▌| 75.8M/79.3M [02:32<00:04, 901kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  96%|█████████▌| 75.9M/79.3M [02:33<00:03, 941kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  96%|█████████▌| 76.0M/79.3M [02:33<00:03, 948kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  96%|█████████▌| 76.1M/79.3M [02:33<00:04, 810kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  96%|█████████▌| 76.2M/79.3M [02:33<00:04, 801kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  96%|█████████▌| 76.3M/79.3M [02:33<00:04, 682kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  96%|█████████▌| 76.3M/79.3M [02:33<00:04, 667kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  96%|█████████▋| 76.4M/79.3M [02:33<00:04, 664kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  96%|█████████▋| 76.5M/79.3M [02:33<00:04, 713kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  97%|█████████▋| 76.6M/79.3M [02:34<00:03, 753kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  97%|█████████▋| 76.7M/79.3M [02:34<00:03, 720kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  97%|█████████▋| 76.7M/79.3M [02:34<00:04, 551kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  97%|█████████▋| 76.8M/79.3M [02:34<00:05, 455kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  97%|█████████▋| 77.0M/79.3M [02:34<00:03, 661kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  97%|█████████▋| 77.0M/79.3M [02:34<00:03, 602kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  97%|█████████▋| 77.1M/79.3M [02:35<00:04, 575kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  97%|█████████▋| 77.2M/79.3M [02:35<00:04, 497kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  97%|█████████▋| 77.3M/79.3M [02:35<00:03, 646kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  98%|█████████▊| 77.3M/79.3M [02:35<00:03, 629kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  98%|█████████▊| 77.4M/79.3M [02:35<00:03, 623kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  98%|█████████▊| 77.5M/79.3M [02:35<00:04, 455kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  98%|█████████▊| 77.6M/79.3M [02:36<00:05, 356kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  98%|█████████▊| 77.7M/79.3M [02:36<00:04, 388kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  98%|█████████▊| 78.0M/79.3M [02:36<00:01, 807kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  99%|█████████▊| 78.2M/79.3M [02:36<00:01, 771kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  99%|█████████▊| 78.3M/79.3M [02:36<00:01, 765kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  99%|█████████▉| 78.4M/79.3M [02:37<00:01, 703kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  99%|█████████▉| 78.4M/79.3M [02:37<00:01, 597kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  99%|█████████▉| 78.5M/79.3M [02:37<00:01, 588kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  99%|█████████▉| 78.6M/79.3M [02:37<00:01, 580kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  99%|█████████▉| 78.6M/79.3M [02:37<00:01, 458kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  99%|█████████▉| 78.7M/79.3M [02:38<00:01, 450kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  99%|█████████▉| 78.7M/79.3M [02:38<00:01, 407kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  99%|█████████▉| 78.8M/79.3M [02:38<00:01, 474kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:  99%|█████████▉| 78.9M/79.3M [02:38<00:00, 544kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|█████████▉| 78.9M/79.3M [02:38<00:01, 365kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|█████████▉| 79.0M/79.3M [02:38<00:00, 397kiB/s]
# /home/kamal/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [02:39<00:00, 522kiB/s]
# 100%|██████████| 5/5 [03:03<00:00, 36.76s/it]
# INPUT-OUTPUT PAIR ADDED TO VECTOR DATABASE:
#   ID
#     1
#   INPUT
#     What is the model preference indicated by the customer in the text?
#   OUTPUT
#     # CRM Data Extraction
#
# ## Product Preferences:
# - The product in question is "Mistral-7B," which is stated to be a top-class model.
#
# ## Customer Intentions:
# - The customer intends to make a distinguishing note of the product, which suggests a high degree of interest or perhaps a future purchase intention.
#
# ## Timeframes:
# - No specific timeframes were mentioned in the text.
#
# ## Other Relevant Details:
# - The praise for the "Mistral-7B" as a top-class model could suggest preferences for high-quality or advanced features. This assumption is however not solid and additional data would be useful to confirm it.
# LIST OF MEMOS
#   ID: 1
#     INPUT TEXT: What is the model preference indicated by the customer in the text?
#     OUTPUT TEXT: # CRM Data Extraction
#
# ## Product Preferences:
# - The product in question is "Mistral-7B," which is stated to be a top-class model.
#
# ## Customer Intentions:
# - The customer intends to make a distinguishing note of the product, which suggests a high degree of interest or perhaps a future purchase intention.
#
# ## Timeframes:
# - No specific timeframes were mentioned in the text.
#
# ## Other Relevant Details:
# - The praise for the "Mistral-7B" as a top-class model could suggest preferences for high-quality or advanced features. This assumption is however not solid and additional data would be useful to confirm it.

# %%
# Wrap up.
teachable_agent.close_db()
