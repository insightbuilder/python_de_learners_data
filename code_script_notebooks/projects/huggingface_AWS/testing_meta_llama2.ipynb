# %%
# !pip install git+https://github.com/huggingface/transformers.git bitsandbytes datasets > /dev/null
# Out:
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-fmdtydey

# %%
# !pip install -q -U git+https://github.com/huggingface/peft.git
# !pip install -q -U git+https://github.com/huggingface/accelerate.git
# !pip install -q -U einops
# !pip install -q -U safetensors
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 2.3 MB/s eta 0:00:00
#   Building wheel for peft (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for accelerate (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 1.5 MB/s eta 0:00:00

# %%
from huggingface_hub import login

login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import torch
from transformers import BitsAndBytesConfig

quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
)

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-chat-hf")
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-2-7b-chat-hf",
                                            device_map="auto",
                                          quantization_config=quantization_config,
                                            resume_download=True)
# Out:
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)of-00002.safetensors:  56%|#####5    | 1.95G/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/167 [00:00<?, ?B/s]

# %%
import torch
import transformers

pipeline = transformers.pipeline(
        "text-generation",
        model=model,
        tokenizer=tokenizer,
        use_cache=True,
        device_map="auto",
        max_length=296,
        do_sample=True,
        top_k=10,
        num_return_sequences=1,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.eos_token_id,
)

# %%
pipeline("Explain me boolean operators")
# Out:
# [{'generated_text': 'Explain me boolean operators in Oracle"\n everybody knows what a boolean operator is, right? Well, actually, it turns out there are several types of boolean operators, and some of them may surprise you.\nIn this article, we\'ll take a closer look at the different types of boolean operators in Oracle, their syntax, and how they can be used to simplify complex queries and improve performance.\nSo, without further ado, let\'s dive in!\n1. AND operator\nThe most commonly used boolean operator is the AND operator (&). It is used to combine two or more conditions that must all be true in order for the statement to be true. Here are some examples:\nORACLE> SELECT * FROM customers WHERE country = \'USA\' AND city = \'New York\';\nSELECT * FROM customers WHERE country = \'USA\' AND city = \'New York\';\nThe above query will return all the rows from the customere table where the country is \'USA\' and the city is \'New York\'.\n2. OR operator\nThe OR operator (|) is used to combine two or more conditions where at least one condition must be true for the statement to be true. Here are some examples:\nORACLE> SELECT * FROM customers WHERE age > 25 OR gender = \'Female\';\nSELECT * FROM customers WHERE age > 25 OR gender = \'Female\';\nThe'}]
