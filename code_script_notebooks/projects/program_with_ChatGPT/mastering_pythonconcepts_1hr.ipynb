# %% [markdown]
# ### This notebook will help you to Learn & practice python

# %% [markdown]
# ### Prequisites.
#
# Time : 5 hours (equal to 3 episodes of a Netflix serial!!!)
# Laptop : 4 to 8GB RAM
# Python, Git and Jupyter notebook installed
#
# Python: 30 mins
# 1) https://youtu.be/Csdg3V2k214
#
# Git: 30 mins
#
# 2) https://youtu.be/0-KS_9x_oUM
#
# Jupyter : 30 mins
#
# 3) https://youtu.be/7s9-Wje5_-4
#
# Internet Connection : !!!!

# %%
# !pip install openai, requests, json

# %%
# starting the conversation with chatgpt & savinging it

#!/usr/bin/env python
import json, openai,requests
import warnings
import os
warnings.filterwarnings('ignore')
import datetime
from time import sleep

# %%
openai_key = 'your_key'
openai_org = 'Your_org'

# %%
get_role = input("What role you want me to play: ")
# Out:
# What role you want me to play: Python Master Teacher

# %%
get_role
# Out:
# 'Python Master Teacher'

# %%
#starting prompt
prompt ="""I am complete beginner to Programming and problem solving with 
code.Provide me the list of topics I have to learn in to Program in Python.
Include the file handling and object oriented programming at the end of the list
Under each topic in the list provide me 3 examples that I can execute and 
see the output"""

# %%
prompt
# Out:
# 'I am complete beginner to Programming and problem solving with \ncode. .Provide me the list of topics I have to learn in to Program in Python.\nInclude the file handling and object oriented programming at the end of the list\nUnder each topic in the list provide me 3 examples that I can execute and \nsee the output'

# %%
def extract_summary(org,key,
                    role_player,
                    request_content,
                   file_name='Python_tutorial.txt'):
    openai.organization = org
    openai.api_key= key
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        temperature=0,
        messages=[
            {"role": "system", 
             "content": f"You are a {role_player}"},
            {"role": "assistant", 
             "content": f"I have assumed the role of {role_player}"},
            {"role": "user", 
             "content": request_content}
            ]
        )
    with open(file_name,'a+') as sumry:
        sumry.write(f'Completion for \n {request_content}')
        sumry.write('******Completion starts****** \n')
        sumry.write(str(response['choices'][0]['message']['content']))
        sumry.write('*****Completion ends****** \n')
    return response['choices'][0]['message']['content']

# %%
list_topics = extract_summary(org=openai_org,key=openai_key,
                             request_content=prompt,
                             role_player=get_role)

# %%
print(list_topics)
# Out:
# Sure, here is a list of topics you should learn to program in Python:
#
# 1. Variables and Data Types
#    - Integers, Floats, Strings
#    - Boolean values
#    - Type conversion
#
#    Example:
#    ```
#    # Integer
#    x = 5
#    print(x)
#
#    # Float
#    y = 3.14
#    print(y)
#
#    # String
#    name = "John"
#    print(name)
#
#    # Boolean
#    is_true = True
#    print(is_true)
#
#    # Type conversion
#    x = 5
#    y = float(x)
#    print(y)
#    ```
#
# 2. Operators and Expressions
#    - Arithmetic operators
#    - Comparison operators
#    - Logical operators
#
#    Example:
#    ```
#    # Arithmetic operators
#    x = 5
#    y = 3
#    print(x + y)
#    print(x - y)
#    print(x * y)
#    print(x / y)
#
#    # Comparison operators
#    x = 5
#    y = 3
#    print(x > y)
#    print(x < y)
#    print(x == y)
#
#    # Logical operators
#    x = 5
#    y = 3
#    z = 7
#    print(x > y and x < z)
#    print(x > y or x > z)
#    print(not(x > y))
#    ```
#
# ...

# %%
x = 5
print(x)
# Out:
# 5

# %%
y = 3.14
print(y)
# Out:
# 3.14

# %%
z = float(x)
z
# Out:
# 5.0

# %%
x = 5
y = 3
z = 7
print(x < y and x < z)
print(x > y or x > z)
print(not(x > y))
# Out:
# False
# True
# False

# %%
#starting prompt
prompt_level2 ="""I have the list of topics and examples for beginner
python programming. Provide me a 30 words layman explanation on each of the Beginner
Python programming topics.Include the file handling and object oriented programming 
at the end of the topics."""

# %%
list_explanation = extract_summary(org=openai_org,key=openai_key,
                                  request_content=prompt_level2,
                                  role_player=get_role)

# %%
print(list_explanation)
# Out:
# Sure, I can provide a brief explanation of each topic. Here they are:
#
# 1. Variables: Variables are used to store data in Python. They can hold different types of data such as numbers, strings, and lists.
#
# 2. Data Types: Python has several built-in data types such as integers, floats, strings, and booleans. Understanding data types is important for writing effective code.
#
# 3. Operators: Operators are used to perform operations on variables and values. Examples include arithmetic operators (+, -, *, /) and comparison operators (==, !=, <, >).
#
# 4. Conditional Statements: Conditional statements allow you to execute different code based on certain conditions. Examples include if statements and while loops.
#
# 5. Functions: Functions are reusable blocks of code that perform a specific task. They can take in arguments and return values.
#
# ...

# %%
#starting prompt
prompt_level3 ="""I have the list of topics and examples for beginner
python programming. Provide me a real world application on each of the Beginner
Python programming topics.Each application must include 2 python code examples. 
Include the file handling and object oriented programming at the end of the topics."""

# %%
list_application = extract_summary(org=openai_org,
                                   key=openai_key,
                                  role_player=get_role,
                                request_content=prompt_level3)

# %%
print(list_application)
# Out:
# Sure, I can provide you with real-world applications and examples for each of the beginner Python programming topics. Here they are:
#
# 1. Variables and Data Types:
# Real-world application: A simple calculator program that takes two numbers as input from the user and performs basic arithmetic operations on them.
#
# Example 1:
#
# ```
# num1 = int(input("Enter first number: "))
# num2 = int(input("Enter second number: "))
#
# addition = num1 + num2
# subtraction = num1 - num2
# multiplication = num1 * num2
# division = num1 / num2
#
# print("Addition: ", addition)
# print("Subtraction: ", subtraction)
# print("Multiplication: ", multiplication)
# print("Division: ", division)
# ```
#
# Example 2:
#
# ```
# name = "John"
# age = 25
# height = 5.8
#
# print("My name is", name)
# print("I am", age, "years old")
# print("My height is", height, "feet")
# ```
#
# 2. Conditional Statements:
# ...

# %%
num = int(input("Enter a number: "))

for i in range(1, 11):
    print(num, "x", i, "=", num*i)
# Out:
# Enter a number: 10
# 10 x 1 = 10
# 10 x 2 = 20
# 10 x 3 = 30
# 10 x 4 = 40
# 10 x 5 = 50
# 10 x 6 = 60
# 10 x 7 = 70
# 10 x 8 = 80
# 10 x 9 = 90
# 10 x 10 = 100

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

addition = num1 + num2
subtraction = num1 - num2
multiplication = num1 * num2
division = num1 / num2

print("Addition: ", addition)
print("Subtraction: ", subtraction)
print("Multiplication: ", multiplication)
print("Division: ", division)
# Out:
# Enter first number: 10
# Enter second number: 25
# Addition:  35
# Subtraction:  -15
# Multiplication:  250
# Division:  0.4

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("You are eligible to vote")
else:
    print("You are not eligible to vote")
# Out:
# Enter your age: 26
# You are eligible to vote

# %%
#starting prompt
prompt_level4 ="""I have good understanding of python programming. 
Provide me 15 real world problems that I can solve by coding in 
Python.For Each problem include the problem statement, solution explanation
and python code example. Include the file handling and object oriented 
programming at the end of the topics."""

# %%
list_prob_code = extract_summary(org=openai_org,key=openai_key,
                                role_player=get_role, 
                                 request_content=prompt_level4)

# %%
myprompt = """Code ==> temperatures = []
for i in range(7):
    temp = float(input("Enter temperature for day " + str(i+1) + ": "))
    temperatures.append(temp)
average_temp = sum(temperatures) / len(temperatures)
print("The average temperature for the week is:", round(average_temp, 2))
Please provide me the alternate way to implement the [Code]"""

# %%
myprompt_reply = extract_summary(org=openai_org, key=openai_key,
                                role_player=get_role,request_content=myprompt)

# %%
print(list_prob_code)
# Out:
# Sure, here are 15 real-world problems that you can solve using Python:
#
# 1. Problem Statement: Create a program that calculates the average temperature for a given week.
#
# Solution Explanation: The program will prompt the user to enter the temperature for each day of the week and then calculate the average temperature for the week.
#
# Python Code Example:
#
# ```python
# temperatures = []
# for i in range(7):
#     temp = float(input("Enter temperature for day " + str(i+1) + ": "))
#     temperatures.append(temp)
# average_temp = sum(temperatures) / len(temperatures)
# print("The average temperature for the week is:", round(average_temp, 2))
# ```
#
# 2. Problem Statement: Create a program that converts Celsius to Fahrenheit.
#
# Solution Explanation: The program will prompt the user to enter a temperature in Celsius and then convert it to Fahrenheit.
#
# Python Code Example:
#
# ```python
# celsius = float(input("Enter temperature in Celsius: "))
# ...

# %%
temperatures = []
for i in range(7):
    temp = float(input("Enter temperature for day " + str(i+1) + ": "))
    temperatures.append(temp)
average_temp = sum(temperatures) / len(temperatures)
print("The average temperature for the week is:", round(average_temp, 2))
# Out:
# Enter temperature for day 1: 12
# Enter temperature for day 2: 25
# Enter temperature for day 3: 35
# Enter temperature for day 4: 48
# Enter temperature for day 5: 25
# Enter temperature for day 6: 35
# Enter temperature for day 7: 56
# The average temperature for the week is: 33.71

# %%
try:
    x = int(input("Enter a number: "))
    y = 10 / x
    print("The result is:", y)
except ValueError:
    print("Invalid input. Please enter a number.")
except ZeroDivisionError:
    print("Cannot divide by zero.")
# Out:
# Enter a number: 0
# Cannot divide by zero.

# %%
#starting prompt
prompt_level5 ="""I have better understanding of python programming in 
the real world. Generate 1 project idea for a full stack application 
involving supply chain and manufacturing using python. Thing step by step 
about the projects. Then list the python libraries and example code  
that is required for each step."""

# %%
list_capstone = extract_summary(org=openai_org,key=openai_key,
                               role_player=get_role,
                               request_content=prompt_level5)

# %%
print(list_capstone)
# Out:
# One project idea for a full stack application involving supply chain and manufacturing using Python could be a system for tracking inventory and production in a manufacturing facility. This system would allow managers to monitor inventory levels, track production progress, and generate reports on production efficiency.
#
# Step 1: Design the database schema
# - Use SQLAlchemy to create a database schema for storing inventory and production data
# - Example code:
# ```
# from sqlalchemy import create_engine, Column, Integer, String
# from sqlalchemy.ext.declarative import declarative_base
# from sqlalchemy.orm import sessionmaker
#
# engine = create_engine('sqlite:///inventory.db')
# Base = declarative_base()
#
# class Product(Base):
#     __tablename__ = 'products'
#     id = Column(Integer, primary_key=True)
#     name = Column(String)
#     quantity = Column(Integer)
#     # add more columns as needed
#
# Base.metadata.create_all(engine)
# Session = sessionmaker(bind=engine)
# ...
