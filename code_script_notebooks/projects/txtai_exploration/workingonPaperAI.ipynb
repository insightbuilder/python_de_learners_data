# %%
# !pip -q install txtai[all] paperai langchain scipy==1.10.0 > /dev/null

# %%
# Download NLTK data
# !python -c "import nltk; nltk.download('punkt')"
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# Download data
# !mkdir -p paperai
# !wget -N https://github.com/neuml/paperai/releases/download/v1.10.0/tests.tar.gz
# !tar -xvzf tests.tar.gz

# %%
# !python -m paperai.index paperai

# %%
# !python -m paperai.query "COVID-19 and hypertension" 2 paperai 0.75

# %%
# !pip -q install codequestion
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for html2markdown (setup.py) ... done

# %%
# !python -m codequestion.download
# Out:
# Downloading model from https://github.com/neuml/codequestion/releases/download/v2.0.0/cqmodel.zip to /tmp/cqmodel.zip
# 100% 726M/726M [00:07<00:00, 95.5MB/s]
# Decompressing model to /root/.codequestion
# Download complete

# %%
# !codequestion
# Out:
# 2023-04-20 13:19:58.871020: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# .topics
# Loading model from /root/.codequestion/models/stackexchange
# codequestion console
# >>> .topics
# bootstrap_twitter_css_html
# Using Bootstrap and my own CSS together (464562)
#
# rust_how_do_what
# What is the Rust type keyword? (483723)
#
# git_how_commit_branch
# Finding what branch a Git commit came from (131079)
#
# matplotlib_python_plot_how
# How do I tell matplotlib that I am done with a plot? (73473)
#
# uitableview_ios_iphone_objective
# How to display the UITableView programmatically? (147198)
#
# maven_java_how_plugin
# How to use properties-maven-plugin? (489388)
#
# google_maps_api_javascript
# Google Maps API - Map Is Not Loaded (366324)
#
# framework_entity_net_ef
# Using EF 4 on .NET 3.5 SP1 (125227)
#
# powershell_how_windows_from
# How can I get all window handles by a process in Powershell? (455085)
#
# ggplot2_plot_ggplot_how
# How to plot one variable in ggplot? (342553)
#
# >>>
# bootstrap_twitter_css_html
# Using Bootstrap and my own CSS together (464562)
#
# rust_how_do_what
# What is the Rust type keyword? (483723)
#
# git_how_commit_branch
# Finding what branch a Git commit came from (131079)
#
# matplotlib_python_plot_how
# How do I tell matplotlib that I am done with a plot? (73473)
#
# uitableview_ios_iphone_objective
# How to display the UITableView programmatically? (147198)
#
# maven_java_how_plugin
# How to use properties-maven-plugin? (489388)
#
# google_maps_api_javascript
# Google Maps API - Map Is Not Loaded (366324)
#
# framework_entity_net_ef
# Using EF 4 on .NET 3.5 SP1 (125227)
#
# powershell_how_windows_from
# How can I get all window handles by a process in Powershell? (455085)
#
# ggplot2_plot_ggplot_how
# How to plot one variable in ggplot? (342553)
#
# >>>
# bootstrap_twitter_css_html
# Using Bootstrap and my own CSS together (464562)
#
# rust_how_do_what
# What is the Rust type keyword? (483723)
#
# git_how_commit_branch
# Finding what branch a Git commit came from (131079)
#
# matplotlib_python_plot_how
# How do I tell matplotlib that I am done with a plot? (73473)
#
# uitableview_ios_iphone_objective
# How to display the UITableView programmatically? (147198)
#
# maven_java_how_plugin
# How to use properties-maven-plugin? (489388)
#
# google_maps_api_javascript
# Google Maps API - Map Is Not Loaded (366324)
#
# framework_entity_net_ef
# Using EF 4 on .NET 3.5 SP1 (125227)
#
# powershell_how_windows_from
# How can I get all window handles by a process in Powershell? (455085)
#
# ggplot2_plot_ggplot_how
# How to plot one variable in ggplot? (342553)
#
# >>> using my own css
# Question (by 100052): Best Practices - CSS Theming [0.724004]
# Id: 155416
# Last Activity: 2010-09-09T18:07:03.277
# Tags: css
# Answer (by 14877):
#
# You should look into SASS, specifically their "Mixins" feature. It takes CSS and
# introduces a very DRY programmatic approach. You can override existing classes
# with it, making it perfect for what I think you're trying to do.
#
# ]8;id=494552;http://sass-lang.com/\Link]8;;\
#
# Reference: https://stackoverflow.com/questions/3662351
#
# >>> using ggplot2
# Question (by 719383): ggplot2 return values [0.848099]
# Id: 321200
# Last Activity: 2022-05-24T18:34:10.483
# Tags: r ggplot2
# Answer (by 11911397):
#
# In ggplot2 (3.3.5), I can not get access to the returned data frame with
# ggplot2:::print.ggplot(), but I get success with ggplot_build:
#
#
#  simple <- data.frame(x = rep(1:10, each = 2))
#  tmp <- ggplot(data=simple) + stat_bin(aes(x), binwidth=0.1)
#  # with ggplot_build
#  x <- ggplot_build(tmp)
#  head(x[["data"]][[1]])
#  #   y count   x xmin xmax density ncount ndensity flipped_aes PANEL group ymin
#  ymax colour   fill size linetype alpha
#  # 1 2     2 1.0 0.95 1.05       1      1        1       FALSE     1    -1    0
#  2     NA grey35  0.5        1    NA
#  # 2 0     0 1.1 1.05 1.15       0      0        0       FALSE     1    -1    0
#  0     NA grey35  0.5        1    NA
#  # 3 0     0 1.2 1.15 1.25       0      0        0       FALSE     1    -1    0
#  0     NA grey35  0.5        1    NA
#  # 4 0     0 1.3 1.25 1.35       0      0        0       FALSE     1    -1    0
#  0     NA grey35  0.5        1    NA
#  # 5 0     0 1.4 1.35 1.45       0      0        0       FALSE     1    -1    0
#  0     NA grey35  0.5        1    NA
#  # 6 0     0 1.5 1.45 1.55       0      0        0       FALSE     1    -1    0
#  0     NA grey35  0.5        1    NA
#
#
# Reference: https://stackoverflow.com/questions/12267970
#
# >>> ggplot2
# Question (by 3283617): ggplot equivalent for matplot [0.825735]
# Id: 495602
# Last Activity: 2015-06-22T15:14:15.230
# Tags: r ggplot2
# Answer (by 5020008):
#
# You can create a similar plot in ggplot, but you will need to do some reshaping
# of the data first.
#
#
#  library(reshape2)
#
#  #ggplot needs a dataframe
#  data <- as.data.frame(data)
#  #id variable for position in matrix
#  data$id <- 1:nrow(data)
#  #reshape to long format
#  plot_data <- melt(data,id.var="id")
#
#
#  #plot
#  ggplot(plot_data, aes(x=id,y=value,group=variable,colour=variable)) +
#    geom_point()+
#    geom_line(aes(lty=variable)) +
#    scale_y_log10(breaks=c(1,2,5,10,25))
#
#
# 🌆 ]8;id=561763;https://i.stack.imgur.com/yHDjA.png\enter image description here]8;;\ My output:
#
# Reference: https://stackoverflow.com/questions/30977249
#
# >>> ggplot
# Question (by 3283617): ggplot equivalent for matplot [0.786437]
# Id: 495602
# Last Activity: 2015-06-22T15:14:15.230
# Tags: r ggplot2
# Answer (by 5020008):
#
# You can create a similar plot in ggplot, but you will need to do some reshaping
# of the data first.
#
#
#  library(reshape2)
#
#  #ggplot needs a dataframe
#  data <- as.data.frame(data)
#  #id variable for position in matrix
#  data$id <- 1:nrow(data)
#  #reshape to long format
#  plot_data <- melt(data,id.var="id")
#
#
#  #plot
#  ggplot(plot_data, aes(x=id,y=value,group=variable,colour=variable)) +
#    geom_point()+
#    geom_line(aes(lty=variable)) +
#    scale_y_log10(breaks=c(1,2,5,10,25))
#
#
# 🌆 ]8;id=259868;https://i.stack.imgur.com/yHDjA.png\enter image description here]8;;\ My output:
#
# Reference: https://stackoverflow.com/questions/30977249
#
# >>> Traceback (most recent call last):
#   File "/usr/lib/python3.9/cmd.py", line 126, in cmdloop
#     line = input(self.prompt)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/codequestion", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.9/dist-packages/codequestion/console.py", line 132, in main
#     Console().cmdloop()
#   File "/usr/lib/python3.9/cmd.py", line 145, in cmdloop
#     readline.set_completer(self.old_completer)
# KeyboardInterrupt
# ^C
