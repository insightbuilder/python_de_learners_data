# %%
## Notebook explores the Matrix Nio Library 
## ensure you have done the pip install matrix-nio[e2ee]

# !pip freeze | grep mat
# Out:
# Automat==22.10.0
# matplotlib==3.6.3
# matplotlib-inline==0.1.6
# mpmath==0.0.0
# syslog-rfc5424-formatter==1.2.3
