# %%
# !pip -q install langchain huggingface_hub huggingface transformers > /dev/null

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = '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'

# %%
from langchain import PromptTemplate, HuggingFaceHub, LLMChain

template = "{question}"
prompt = PromptTemplate(template=template, input_variables=["question"])

# %%
models = ["OpenAssistant/oasst-sft-1-pythia-12b",
          "stabilityai/stablelm-base-alpha-7b"]

# %%
llm_chain = LLMChain(prompt=prompt, 
                     llm=HuggingFaceHub(repo_id="stabilityai/stablelm-base-alpha-7b",
                                        model_kwargs={"temperature":0.5, 
                                                      "max_length":128}))

# %%
question = "when did the last olympic take place? "

# %%
print(llm_chain.run(question))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-c64533dbff56> in <cell line: 1>()
# ----> 1 print(llm_chain.run(question))
#
# /usr/local/lib/python3.9/dist-packages/langchain/chains/base.py in run(self, *args, **kwargs)
#     211             if len(args) != 1:
#     212                 raise ValueError("`run` supports only one positional argument.")
# --> 213             return self(args[0])[self.output_keys[0]]
#     214
#     215         if kwargs and not args:
#
# /usr/local/lib/python3.9/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs)
#     114         except (KeyboardInterrupt, Exception) as e:
#     115             self.callback_manager.on_chain_error(e, verbose=self.verbose)
# --> 116             raise e
#     117         self.callback_manager.on_chain_end(outputs, verbose=self.verbose)
# ...

# %%
llm=HuggingFaceHub(repo_id="stabilityai/stablelm-base-alpha-7b",
                                        model_kwargs={"temperature":0.5, 
                                                      "max_length":128})

# %%
llm(question)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-cb2141bfa4e9> in <cell line: 1>()
# ----> 1 llm(question)
#
# /usr/local/lib/python3.9/dist-packages/langchain/llms/base.py in __call__(self, prompt, stop)
#     244     def __call__(self, prompt: str, stop: Optional[List[str]] = None) -> str:
#     245         """Check Cache and run the LLM on the given prompt and input."""
# --> 246         return self.generate([prompt], stop=stop).generations[0][0].text
#     247
#     248     @property
#
# /usr/local/lib/python3.9/dist-packages/langchain/llms/base.py in generate(self, prompts, stop)
#     138             except (KeyboardInterrupt, Exception) as e:
#     139                 self.callback_manager.on_llm_error(e, verbose=self.verbose)
# --> 140                 raise e
#     141             self.callback_manager.on_llm_end(output, verbose=self.verbose)
# ...

# %%
#Using the llm for retrieval process
from langchain.agents import create_pandas_dataframe_agent
from langchain.llms import OpenAI
import pandas as pd

df = pd.read_csv('/content/space_shortened.csv')

# %%
llm=HuggingFaceHub(repo_id="OpenAssistant/oasst-sft-1-pythia-12b",
                                        model_kwargs={"temperature":0.01, 
                                                      "max_length":1024})

# %%
space_agent = create_pandas_dataframe_agent(llm, 
                                      df, 
                                      verbose=True)

# %%
space_agent.run("How many rows are there?")
